# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\DELL\Downloads\cancer_reg.csv",encoding='latin-1')
data.head()
# Out:
#    avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  medIncome  \
# 0       1397.0               469             164.9          489.8      61898
# 1        173.0                70             161.3          411.6      48127
# 2        102.0                50             174.7          349.7      49348
# 3        427.0               202             194.8          430.4      44243
# 4         57.0                26             144.4          350.1      49955
#
#    popEst2015  povertyPercent  studyPerCap           binnedInc  MedianAge  \
# 0      260131            11.2   499.748204   (61494.5, 125635]       39.3
# 1       43269            18.6    23.111234  (48021.6, 51046.4]       33.0
# 2       21026            14.6    47.560164  (48021.6, 51046.4]       45.0
# 3       75882            17.1   342.637253    (42724.4, 45201]       42.8
# 4       10321            12.5     0.000000  (48021.6, 51046.4]       48.3
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3047 entries, 0 to 3046
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avgAnnCount              3047 non-null   float64
#  1   avgDeathsPerYear         3047 non-null   int64
#  2   TARGET_deathRate         3047 non-null   float64
#  3   incidenceRate            3047 non-null   float64
#  4   medIncome                3047 non-null   int64
#  5   popEst2015               3047 non-null   int64
#  6   povertyPercent           3047 non-null   float64
#  7   studyPerCap              3047 non-null   float64
#  8   binnedInc                3047 non-null   object
#  9   MedianAge                3047 non-null   float64
#  10  MedianAgeMale            3047 non-null   float64
#  11  MedianAgeFemale          3047 non-null   float64
#  12  Geography                3047 non-null   object
#  13  AvgHouseholdSize         3047 non-null   float64
# ...

# %%
data.describe()
# Out:
#         avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  \
# count   3047.000000       3047.000000       3047.000000    3047.000000
# mean     606.338544        185.965868        178.664063     448.268586
# std     1416.356223        504.134286         27.751511      54.560733
# min        6.000000          3.000000         59.700000     201.300000
# 25%       76.000000         28.000000        161.200000     420.300000
# 50%      171.000000         61.000000        178.100000     453.549422
# 75%      518.000000        149.000000        195.200000     480.850000
# max    38150.000000      14010.000000        362.800000    1206.900000
#
#            medIncome    popEst2015  povertyPercent  studyPerCap    MedianAge  \
# count    3047.000000  3.047000e+03     3047.000000  3047.000000  3047.000000
# mean    47063.281917  1.026374e+05       16.878175   155.399415    45.272333
# std     12040.090836  3.290592e+05        6.409087   529.628366    45.304480
# ...

# %%
data.isna().sum()
# Out:
# avgAnnCount                   0
# avgDeathsPerYear              0
# TARGET_deathRate              0
# incidenceRate                 0
# medIncome                     0
# popEst2015                    0
# povertyPercent                0
# studyPerCap                   0
# binnedInc                     0
# MedianAge                     0
# MedianAgeMale                 0
# MedianAgeFemale               0
# Geography                     0
# AvgHouseholdSize              0
# PercentMarried                0
# PctNoHS18_24                  0
# PctHS18_24                    0
# PctSomeCol18_24            2285
# PctBachDeg18_24               0
# PctHS25_Over                  0
# PctBachDeg25_Over             0
# PctEmployed16_Over          152
# PctUnemployed16_Over          0
# PctPrivateCoverage            0
# PctPrivateCoverageAlone     609
# PctEmpPrivCoverage            0
# PctPublicCoverage             0
# PctPublicCoverageAlone        0
# PctWhite                      0
# ...

# %% [markdown]
# # Data Visulizations

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.hist(data['TARGET_deathRate'],bins=30,color = 'red',
        edgecolor ='black')
plt.xlabel('Death Rate')
plt.ylabel('Frequency')
plt.title('Histogram of Death Rate')
# Out:
# Text(0.5, 1.0, 'Histogram of Death Rate')

# %% [markdown]
# ## Keypoints from the Histogram
# 1. We can observe outliners in the dataset.
# 2. The data looks like right skewed (slightely positively skewed).
# 3. Mean is slightly greater than median.
# 4. There are 3 peaks in the data.

# %%
plt.figure(figsize =(8,3))
bp = plt.boxplot(data['TARGET_deathRate'],patch_artist = True,vert=0)
colors = ['#00FF00','#0F00FF', '#F00FF0','#FFFF0F']
for patch in bp['boxes']:  
    patch.set_facecolor('#00FF00')  
for whisker in bp['whiskers']:  
    whisker.set(color ='#8E008B',linewidth = 1.4,linestyle =":")  
for cap in bp['caps']:  
    cap.set(color ='#8E008B',linewidth = 2.1)  
for median in bp['medians']:  
    median.set(color ='blue',linewidth = 3)  
for flier in bp['fliers']:  
    flier.set(marker ='D',color ='#d7298c',alpha = 0.6)

# %% [markdown]
# # Keypoints from the Boxplot
# 1. We can conform that there are outliners in the dataset.
# 2. This oultilners will have huge impact while training a model.

# %%
avg_ann_count = data['avgAnnCount'].mean()
std_ann_count = data['avgAnnCount'].std()
print("Mean of avganncount :",avg_ann_count)
print("Standard deviation of avganncount :",std_ann_count)


plt.hist(data['avgAnnCount'],bins=20,color='red',edgecolor='black')
plt.xlabel('avgAnnCount')
plt.ylabel('Frequency')
plt.title("Histogram of avganncount")
plt.show()

plt.boxplot(data['avgAnnCount'],meanline = True,widths=0.5,vert=False)
plt.title('Boxplot of avganncount')
plt.show()

corr= data['avgAnnCount'].corr(data['TARGET_deathRate'])
print("The Correlation between the avganncount and target death rate is ",corr)


plt.scatter(data['avgAnnCount'],data['TARGET_deathRate'])
plt.xlabel('avganncount')
plt.ylabel('target_death rate')
plt.title('scatter plot')
plt.show()
# Out:
# Mean of avganncount : 606.3385437820798
# Standard deviation of avganncount : 1416.3562232267102
# The Correlation between the avganncount and target death rate is  -0.14353161968868813

# %% [markdown]
# # Key interpretations
#
# 1. The mean of avganncount is 606.33, which means that in each county there are anually 606 cancer diagnosed patients.
#
# 2. The Standard deviation of avganncount is 1416.35, tells us how that the data is quite spread out.
# In some counties there may be less cancer diagnosis and there may be high cancer diagnosis annually.
#
# 3. The correlation between avganncount and target deathrate tell us that if the avganncount incereases then the deathrate decreases(shows negative linear relationship)

# %%
from scipy.stats import normaltest

num_col = data.select_dtypes(include=np.number).columns
gaussian_col = []
non_gaussian_col  = []
for col in num_col:
    stat,p = normaltest(data[col])
    alpha = 0.05
    if p>alpha:
        gaussian_col.append(col)
    else:
        non_gaussian_col.append(col)
print(gaussian_col)
# Out:
# ['PctPublicCoverage']

# %%
len(non_gaussian_col)
# Out:
# 31

# %%
fig,axes = plt.subplots(1,1)
for i,col in enumerate(gaussian_col):
    data[col].plot(kind='density',ax=axes,subplots=True)
plt.tight_layout()
plt.show()

# %%
dk = data[gaussian_col].describe()
dk
# Out:
#        PctPublicCoverage
# count        3047.000000
# mean           36.252642
# std             7.841741
# min            11.200000
# 25%            30.900000
# 50%            36.300000
# 75%            41.550000
# max            65.100000

# %%
print('Highest allowed :',dk.iloc[1][0] + 3*dk.iloc[2][0])
print('Lowest allowed :',dk.iloc[1][0] - 3*dk.iloc[2][0])
# Out:
# Highest allowed : 59.77786475520317
# Lowest allowed : 12.72741913058621

# %%
data[(data['PctPublicCoverage'] >59.77786475520317) |
    (data['PctPublicCoverage'] < 12.72741913058621)]
# Out:
#       avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  \
# 176          25.0                10             134.3          359.0
# 209         862.0               283             136.5          364.9
# 1486       1067.0               358             142.9          444.5
# 2713          8.0                 3             203.3          201.3
# 2740        129.0                54             126.1          332.0
#
#       medIncome  popEst2015  povertyPercent  studyPerCap           binnedInc  \
# 176       27627        4596            24.2     0.000000    [22640, 34218.1]
# 209      122641      375629             3.9   449.912014   (61494.5, 125635]
# 1486      51907      118891            10.9    84.110656  (51046.4, 54545.6]
# 2713      68387        5702             9.9     0.000000   (61494.5, 125635]
# 2740      32533       20152            22.8     0.000000    [22640, 34218.1]
#
#       MedianAge  ...  PctPrivateCoverageAlone  PctEmpPrivCoverage  \
# ...
